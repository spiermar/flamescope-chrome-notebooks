# %%
f = open('Profile-20180716T115056', 'r')

# %%
import json

data = json.load(f)

# %%
root_slices = []
events = {}
start = None
end = None

# TODO: parse Complete Events, "X"
# TODO: handle CPU time differences, 
# TODO: handle events where "E" comes before "B"
# TODO: handle "sf" and "stack" properties on Duration Events

for row in data:
    if row['ph'] != 'M':
        if start is None or int(row['ts']) < start:
            start = int(row['ts'])
        if end is None or int(row['ts']) > end:
            end = int(row['ts'])
    if row['ph'] == 'B' or row['ph'] == 'E':
        key = str(row['pid']) + '_' + str(row['tid'])
        if row['ph'] == 'B':
            if key not in events:
                events[key] = { 'ts': row['ts'], 'tts': row['tts'], 'children_count': 0 }
            else:
                events[key]['children_count'] = events[key]['children_count'] + 1
        elif row['ph'] == 'E':
            if events[key]['children_count'] > 0:
                events[key]['children_count'] = events[key]['children_count'] - 1
            else:
                root_slices.append({'start': events[key]['ts'], 'cpu_start': events[key]['tts'], 'end': row['ts'], 'cpu_end': row['tts']})
                del events[key]

# %%
import math

COL_BIN_SIZE = 1000000
ROW_BIN_SIZE = 20000

num_col_bins = math.ceil((end - start) / COL_BIN_SIZE)
num_row_bins = int(COL_BIN_SIZE / ROW_BIN_SIZE)

arr = [[0 for i in range(num_row_bins)] for j in range(num_col_bins)]

# %%
for s in root_slices:
    first_row_index = math.floor((s['start'] - start) / ROW_BIN_SIZE)
    last_row_index = math.ceil((s['end'] - start) / ROW_BIN_SIZE)
    usage = (s['cpu_end'] - s['cpu_start']) / (s['end'] - s['start'])
    for i in range(first_row_index, last_row_index):
        if i > 0:
            col_index = int(i // (COL_BIN_SIZE / ROW_BIN_SIZE))
            row_index = int(math.ceil(i % (COL_BIN_SIZE / ROW_BIN_SIZE)))
        else:
            col_index = 0
            row_index = 0
        arr[col_index][row_index] = arr[col_index][row_index] + usage

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16, 16]

plt.imshow(np.transpose(arr), cmap='hot', origin='lower')
plt.show()

# %%
BIN_SIZE = 20000

chk_arr = [0 for i in range(math.ceil((end - start) / BIN_SIZE))]

# %%
for s in root_slices:
    first_row_index = math.floor((s['start'] - start) / BIN_SIZE)
    last_row_index = math.ceil((s['end'] - start) / BIN_SIZE)
    usage = (s['cpu_end'] - s['cpu_start']) / (s['end'] - s['start'])
    for i in range(first_row_index, last_row_index):
        chk_arr[i] = chk_arr[i] + usage

# %%
plt.rcParams['figure.figsize'] = [16, 8]
plt.plot(chk_arr)
plt.show()
